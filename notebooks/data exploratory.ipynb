# %%
import requests
from datetime import datetime
from pathlib import Path
import pandas as pd

BASE_FILE_PATH = Path('/tmp')
# 'museos/2021-noviembre/museos-03-11-2021' 
file_path_crib = '{category}/{year}-{month:02d}/{category}-{day:02d}-{month:02d}-{year}.csv'

# %%
categories = [
    {
        'name': 'museo',
        'url': 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/4207def0-2ff7-41d5-9095-d42ae8207a5d/download/museos_datosabiertos.csv'
    },
    {
        'name': 'biblios',
        'url': 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/01c6c048-dbeb-44e0-8efa-6944f73715d7/download/biblioteca_popular.csv'
    }
]

# %% [markdown]
# # Museos

# %%
category_dict = categories[0]
r = requests.get(category_dict['url'])
r.encoding = 'utf-8'

# %% [markdown]
# ## Extract

# %%
now = datetime.now()
file_path = file_path_crib.format(category=category_dict['name'], year=now.year, month=now.month, day = now.day)

museo_path = BASE_FILE_PATH / file_path
# If there's no parent directory, this will throw FileNotFoundError.
museo_path.parent.mkdir(parents=True, exist_ok=True)

# Save file
with open(museo_path, 'w') as f_out:
    f_out.write(r.text)

# %% [markdown]
# ## Transform

# %%
df = pd.read_csv(museo_path)
df.head(2)
# Out:
#    Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0  6588100            6            6588            NaN
# 1  6077010            6            6077            NaN
#
#                             categoria subcategoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial       Museos  Buenos Aires   Arrecifes
#
#                                            nombre               direccion  \
# 0  Archivo Y Museo Histórico Gral. Julio De Vedia           Libertad 1191
# 1          Museo Y Archivo Histórico De Arrecifes  Gerardo Risso y España
#
#    ...                        Mail                    Web    Latitud  \
# 0  ...  archivoymuseo@yahoo.com.ar  www.portaldel9.com.ar -35.441762
# 1  ...  museoarrecifes@hotmail.com                    NaN -34.066970
#
#     Longitud   TipoLatitudLongitud Info_adicional  fuente  jurisdiccion  \
# 0 -60.887598  Localización precisa            NaN   DNPyM     Municipal
# 1 -60.102555  Localización precisa            NaN   DNPyM     Municipal
#
#   año_inauguracion actualizacion
# 0           1920.0          2017
# 1           1972.0          2017
#
# [2 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observaciones',
#        'categoria', 'subcategoria', 'provincia', 'localidad', 'nombre',
#        'direccion', 'piso', 'CP', 'cod_area', 'telefono', 'Mail', 'Web',
#        'Latitud', 'Longitud', 'TipoLatitudLongitud', 'Info_adicional',
#        'fuente', 'jurisdiccion', 'año_inauguracion', 'actualizacion'],
#       dtype='object')

# %%
# Map the columns as the statement says
renamed_columns = {
    "Cod_Loc": "cod_localidad",
    "IdProvincia": "id_provincia",
    "IdDepartamento": "id_departamento",
    "categoria": "categoría",
    "direccion": "domicilio",
    "CP": "código postal",
    "telefono": "número de teléfono",
    "Mail": "mail",
    "Web": "web",
}

df = df.rename(columns = renamed_columns)

museos_columns = [
    "cod_localidad",
    "id_provincia",
    "id_departamento",
    "categoría",
    "domicilio",
    "código postal",
    "número de teléfono",
    "mail",
    "web",
]

# Taking only the necessary columns
df_museos = df[museos_columns]

# %% [markdown]
# # Bibliotecas

# %%
category_dict = categories[1]
r = requests.get(category_dict['url'])
r.encoding = 'utf-8'

# %% [markdown]
# ## Extract

# %%
now = datetime.now()
file_path = file_path_crib.format(category=category_dict['name'], year=now.year, month=now.month, day = now.day)

biblio_path = BASE_FILE_PATH / file_path
# If there's no parent directory, this will throw FileNotFoundError.
biblio_path.parent.mkdir(parents=True, exist_ok=True)

# Save file
with open(biblio_path, 'w') as f_out:
    f_out.write(r.text)

# %% [markdown]
# ## Transform

# %%
df = pd.read_csv(biblio_path)
df.head(2)
# Out:
#     Cod_Loc  IdProvincia  IdDepartamento  Observacion              Categoría  \
# 0  70049060           70           70049          NaN  Bibliotecas Populares
# 1   2000010            2            2000          NaN  Bibliotecas Populares
#
#    Subcategoria                        Provincia  \
# 0           NaN                         San Juan
# 1           NaN  Ciudad Autónoma de Buenos Aires
#
#                       Departamento               Localidad  \
# 0                          Iglesia                   Rodeo
# 1  Ciudad Autonoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         Nombre  ...  \
# 0         Biblioteca Popular Juan P. Garramuno  ...
# 1  Biblioteca Popular Helena Larroque de Roffo  ...
#
#                            Mail  Web Información adicional    Latitud  \
# 0                           s/d  NaN                   NaN -30.209250
# 1  asociacionroffo@yahoo.com.ar  NaN                   NaN -34.598461
#
#     Longitud   TipoLatitudLongitud   Fuente  Tipo_gestion  año_inicio  \
# 0 -69.130117  Localización precisa  CONABIP   Comunitaria      1930.0
# 1 -58.494690  Localización precisa  CONABIP   Comunitaria      1916.0
#
#    Año_actualizacion
# 0               2018
# 1               2018
#
# [2 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observacion', 'Categoría',
#        'Subcategoria', 'Provincia', 'Departamento', 'Localidad', 'Nombre',
#        'Domicilio', 'Piso', 'CP', 'Cod_tel', 'Teléfono', 'Mail', 'Web',
#        'Información adicional', 'Latitud', 'Longitud', 'TipoLatitudLongitud',
#        'Fuente', 'Tipo_gestion', 'año_inicio', 'Año_actualizacion'],
#       dtype='object')

# %%
 # Map the columns as the statement says
renamed_columns = {
    "Cod_Loc": "cod_localidad",
    "IdProvincia": "id_provincia",
    "IdDepartamento": "id_departamento",
    'Provincia': 'provincia',
    "Categoría": "categoría",
    "Domicilio": "domicilio",
    "CP": "código postal",
    "Localidad": "localidad",
    "Nombre": "nombre",
    'Domicilio': "domicilio",
    "Teléfono": "número de teléfono",
    "Mail": "mail",
    "Web": "web",
}

df = df.rename(columns = renamed_columns)

biblios_columns = [
    "cod_localidad",
    "id_provincia",
    "id_departamento",
    "categoría",
    "provincia",
    "localidad",
    "nombre",
    "domicilio",
    "código postal",
    "número de teléfono",
    "mail",
    "web",
]

# Taking only the necessary columns
df_biblios = df[biblios_columns]

# %%
# Checking if there's any NULL in the column "id_departamento"
df_biblios["id_departamento"].isna().unique()
# Out:
# array([False])

# %%
# Generating dict with all the dfs

df_dict = {"museos": df_museos,"biblios": df_biblios}
joined_df = pd.concat(df_dict, axis=0)
joined_df.dtypes
# Out:
# cod_localidad          int64
# id_provincia           int64
# id_departamento        int64
# categoría             object
# domicilio             object
# código postal         object
# número de teléfono    object
# mail                  object
# web                   object
# provincia             object
# localidad             object
# nombre                object
# dtype: object

# %%
# Count by category (as_index=False is effectively “SQL-style” grouped output.)
joined_df.groupby('categoría', as_index=False).size()
# Out:
#                             categoría  size
# 0               Bibliotecas Populares  2017
# 1  Espacios de Exhibición Patrimonial  1182

# %%
# Count by source
sources_list = list()
for name, df in df_dict.items():
    sources_list.append({'source': name, 'count': df.size})

pd.DataFrame(sources_list)
# Out:
#     source  count
# 0   museos  10638
# 1  biblios  24204

# %%
# Count by provincia and category
joined_df.groupby(['categoría', 'provincia'], as_index=False).size()
# Out:
#                 categoría                        provincia  size
# 0   Bibliotecas Populares                     Buenos Aires   543
# 1   Bibliotecas Populares                        Catamarca    38
# 2   Bibliotecas Populares                            Chaco    70
# 3   Bibliotecas Populares                           Chubut    48
# 4   Bibliotecas Populares  Ciudad Autónoma de Buenos Aires    43
# 5   Bibliotecas Populares                       Corrientes    58
# 6   Bibliotecas Populares                          Córdoba   185
# 7   Bibliotecas Populares                       Entre Ríos    58
# 8   Bibliotecas Populares                          Formosa    25
# 9   Bibliotecas Populares                            Jujuy    40
# 10  Bibliotecas Populares                         La Pampa    72
# 11  Bibliotecas Populares                         La Rioja    24
# 12  Bibliotecas Populares                          Mendoza    67
# 13  Bibliotecas Populares                         Misiones    40
# 14  Bibliotecas Populares                          Neuquén    70
# 15  Bibliotecas Populares                        Río Negro    66
# 16  Bibliotecas Populares                            Salta    64
# 17  Bibliotecas Populares                         San Juan    54
# 18  Bibliotecas Populares                         San Luis    45
# 19  Bibliotecas Populares                       Santa Cruz    21
# 20  Bibliotecas Populares                         Santa Fe   272
# 21  Bibliotecas Populares                         Santa Fé     1
# 22  Bibliotecas Populares              Santiago del Estero    67
# 23  Bibliotecas Populares                 Tierra del Fuego     9
# 24  Bibliotecas Populares                          Tucumán    37
